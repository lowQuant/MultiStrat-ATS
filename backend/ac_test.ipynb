# %%
import arcticdb as adb

# %%
ac = adb.Arctic(uri="lmdb://ARCTICDB")

# %%
ac.create_library("strategies",library_options=dynamic_schema=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ac.create_library("strategies",dynamic_schema=True)
#
# TypeError: Arctic.create_library() got an unexpected keyword argument 'dynamic_schema'
